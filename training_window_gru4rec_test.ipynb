# %%
from utils.experiment_setup import gru4rec_vsknn_setups as setups
from utils.gru4rec_train_test_utils import train_test_gru4rec_models
import os

# %%
metric_n = [1, 5, 10, 20]
n_epochs = 10
experiments = {
    "retailrocket_full": {
        "train_path": "data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_train_full.tsv",
        "test_path": "data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_test.tsv"},
    "retailrocket_91D": {
        "train_path": "data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_train_full_91D.tsv",
        "test_path": "data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_test.tsv"},
    "retailrocket_56D": {
        "train_path": "data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_train_full_56D.tsv",
        "test_path": "data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_test.tsv"},
    "retailrocket_28D": {
        "train_path": "data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_train_full_28D.tsv",
        "test_path": "data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_test.tsv"},
    "retailrocket_14D": {
        "train_path": "data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_train_full_14D.tsv",
        "test_path": "data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_test.tsv"},
    "retailrocket_7D": {
        "train_path": "data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_train_full_7D.tsv",
        "test_path": "data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_test.tsv"}
}

# %%
setups_gru4rec = {}
for dataset_key, model_setups in setups.items():
    tmp = {}
    for model_key, params in model_setups.items():
        if "gru4rec" in model_key:
            tmp[model_key] = params
    setups_gru4rec[dataset_key] = tmp
train_test_gru4rec_models(experiments=experiments, setups=setups_gru4rec, n_epochs=n_epochs, m=metric_n)
# Out:
# executing script:
# THEANO_FLAGS=device=cuda0 python ./GRU4Rec/run.py data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_train_full.tsv -t data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_test.tsv -g gru4rec -ps layers=224,loss=bpr-max,bpreg=1.95,logq=0.0,final_act=elu-0.5,hidden_act=tanh,n_epochs=10,batch_size=80,dropout_p_embed=0.5,dropout_p_hidden=0.05,learning_rate=0.05,momentum=0.4,sample_alpha=0.4,n_sample=2048,constrained_embedding=True,embedding=0,adapt=adagrad,item_key=ItemId,session_key=SessionId,time_key=Time -m 1 5 10 20
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# Using cuDNN version 7104 on context None
# Mapped name None to device cuda0: NVIDIA GeForce GTX TITAN X (0000:02:00.0)
# SET   layers                  TO   [224]       (type: <class 'list'>)
# SET   loss                    TO   bpr-max     (type: <class 'str'>)
# SET   bpreg                   TO   1.95        (type: <class 'float'>)
# SET   logq                    TO   0.0         (type: <class 'float'>)
# SET   final_act               TO   elu-0.5     (type: <class 'str'>)
# SET   hidden_act              TO   tanh        (type: <class 'str'>)
# SET   n_epochs                TO   10          (type: <class 'int'>)
# SET   batch_size              TO   80          (type: <class 'int'>)
# SET   dropout_p_embed         TO   0.5         (type: <class 'float'>)
# SET   dropout_p_hidden        TO   0.05        (type: <class 'float'>)
# SET   learning_rate           TO   0.05        (type: <class 'float'>)
# SET   momentum                TO   0.4         (type: <class 'float'>)
# SET   sample_alpha            TO   0.4         (type: <class 'float'>)
# SET   n_sample                TO   2048        (type: <class 'int'>)
# SET   constrained_embedding   TO   True        (type: <class 'bool'>)
# SET   embedding               TO   0           (type: <class 'int'>)
# SET   adapt                   TO   adagrad     (type: <class 'str'>)
# SET   item_key                TO   ItemId      (type: <class 'str'>)
# SET   session_key             TO   SessionId   (type: <class 'str'>)
# SET   time_key                TO   Time        (type: <class 'str'>)
# Loading training data...
# Loading data from TAB separated file: data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_train_full.tsv
# Started training
# The dataframe is already sorted by SessionId, Time
# Created sample store with 4882 batches of samples (type=GPU)
# Epoch1 --> loss: 0.484738 	(11.64s) 	[601.17 mb/s | 47657 e/s]
# Epoch2 --> loss: 0.382165 	(11.64s) 	[601.01 mb/s | 47644 e/s]
# Epoch3 --> loss: 0.354093 	(11.60s) 	[603.34 mb/s | 47829 e/s]
# Epoch4 --> loss: 0.339908 	(11.63s) 	[601.43 mb/s | 47677 e/s]
# Epoch5 --> loss: 0.330645 	(11.69s) 	[598.32 mb/s | 47431 e/s]
# Epoch6 --> loss: 0.324084 	(11.67s) 	[599.37 mb/s | 47514 e/s]
# Epoch7 --> loss: 0.319047 	(11.69s) 	[598.69 mb/s | 47460 e/s]
# Epoch8 --> loss: 0.314979 	(11.66s) 	[599.95 mb/s | 47560 e/s]
# Epoch9 --> loss: 0.311610 	(11.67s) 	[599.46 mb/s | 47521 e/s]
# Epoch10 --> loss: 0.308854 	(11.68s) 	[599.19 mb/s | 47500 e/s]
# Total training time: 137.99s
# Loading test data...
# Loading data from TAB separated file: data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_test.tsv
# Starting evaluation (cut-off=1, using standard mode for tiebreaking)
# Measuring Recall@1 and MRR@1
# Evaluation took 6.05s
# Recall@1: 0.128102 MRR@1: 0.128102
# Starting evaluation (cut-off=5, using standard mode for tiebreaking)
# Measuring Recall@5 and MRR@5
# Evaluation took 1.65s
# Recall@5: 0.324456 MRR@5: 0.198899
# Starting evaluation (cut-off=10, using standard mode for tiebreaking)
# Measuring Recall@10 and MRR@10
# Evaluation took 1.65s
# Recall@10: 0.421439 MRR@10: 0.211795
# Starting evaluation (cut-off=20, using standard mode for tiebreaking)
# Measuring Recall@20 and MRR@20
# Evaluation took 1.63s
# Recall@20: 0.519569 MRR@20: 0.218630
# executing script:
# THEANO_FLAGS=device=cuda0 python ./GRU4Rec/run.py data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_train_full_91D.tsv -t data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_test.tsv -g gru4rec -ps layers=228,loss=bpr-max,bpreg=0.25,logq=0.0,final_act=linear,hidden_act=tanh,n_epochs=10,batch_size=32,dropout_p_embed=0.5,dropout_p_hidden=0.1,learning_rate=0.055,momentum=0.2,sample_alpha=0.3,n_sample=2048,constrained_embedding=True,embedding=0,adapt=adagrad,item_key=ItemId,session_key=SessionId,time_key=Time -m 1 5 10 20
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# Using cuDNN version 7104 on context None
# Mapped name None to device cuda0: NVIDIA GeForce GTX TITAN X (0000:02:00.0)
# SET   layers                  TO   [228]       (type: <class 'list'>)
# SET   loss                    TO   bpr-max     (type: <class 'str'>)
# SET   bpreg                   TO   0.25        (type: <class 'float'>)
# SET   logq                    TO   0.0         (type: <class 'float'>)
# SET   final_act               TO   linear      (type: <class 'str'>)
# SET   hidden_act              TO   tanh        (type: <class 'str'>)
# SET   n_epochs                TO   10          (type: <class 'int'>)
# SET   batch_size              TO   32          (type: <class 'int'>)
# SET   dropout_p_embed         TO   0.5         (type: <class 'float'>)
# SET   dropout_p_hidden        TO   0.1         (type: <class 'float'>)
# SET   learning_rate           TO   0.055       (type: <class 'float'>)
# SET   momentum                TO   0.2         (type: <class 'float'>)
# SET   sample_alpha            TO   0.3         (type: <class 'float'>)
# SET   n_sample                TO   2048        (type: <class 'int'>)
# SET   constrained_embedding   TO   True        (type: <class 'bool'>)
# SET   embedding               TO   0           (type: <class 'int'>)
# SET   adapt                   TO   adagrad     (type: <class 'str'>)
# SET   item_key                TO   ItemId      (type: <class 'str'>)
# SET   session_key             TO   SessionId   (type: <class 'str'>)
# SET   time_key                TO   Time        (type: <class 'str'>)
# Loading training data...
# Loading data from TAB separated file: data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_train_full_91D.tsv
# Started training
# The dataframe is already sorted by SessionId, Time
# Created sample store with 4882 batches of samples (type=GPU)
# Epoch1 --> loss: 0.433276 	(18.18s) 	[636.74 mb/s | 20334 e/s]
# Epoch2 --> loss: 0.283991 	(18.18s) 	[636.48 mb/s | 20326 e/s]
# Epoch3 --> loss: 0.247230 	(18.27s) 	[633.55 mb/s | 20232 e/s]
# Epoch4 --> loss: 0.230069 	(18.18s) 	[636.57 mb/s | 20329 e/s]
# Epoch5 --> loss: 0.219642 	(18.22s) 	[635.19 mb/s | 20285 e/s]
# Epoch6 --> loss: 0.211859 	(18.25s) 	[634.03 mb/s | 20248 e/s]
# Epoch7 --> loss: 0.206153 	(18.28s) 	[633.24 mb/s | 20222 e/s]
# Epoch8 --> loss: 0.201527 	(18.25s) 	[634.17 mb/s | 20252 e/s]
# Epoch9 --> loss: 0.197631 	(18.24s) 	[634.39 mb/s | 20259 e/s]
# Epoch10 --> loss: 0.194531 	(18.21s) 	[635.62 mb/s | 20298 e/s]
# Total training time: 202.18s
# Loading test data...
# Loading data from TAB separated file: data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_test.tsv
# Starting evaluation (cut-off=1, using standard mode for tiebreaking)
# Measuring Recall@1 and MRR@1
# Evaluation took 5.78s
# Recall@1: 0.113526 MRR@1: 0.113526
# Starting evaluation (cut-off=5, using standard mode for tiebreaking)
# Measuring Recall@5 and MRR@5
# Evaluation took 1.70s
# Recall@5: 0.305456 MRR@5: 0.181993
# Starting evaluation (cut-off=10, using standard mode for tiebreaking)
# Measuring Recall@10 and MRR@10
# Evaluation took 1.55s
# Recall@10: 0.403244 MRR@10: 0.195079
# Starting evaluation (cut-off=20, using standard mode for tiebreaking)
# Measuring Recall@20 and MRR@20
# Evaluation took 1.54s
# Recall@20: 0.503047 MRR@20: 0.202025
# executing script:
# THEANO_FLAGS=device=cuda0 python ./GRU4Rec/run.py data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_train_full_56D.tsv -t data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_test.tsv -g gru4rec -ps layers=128,loss=bpr-max,bpreg=0.35,logq=0.0,final_act=elu-1,hidden_act=tanh,n_epochs=10,batch_size=32,dropout_p_embed=0.5,dropout_p_hidden=0.1,learning_rate=0.15,momentum=0.1,sample_alpha=0.2,n_sample=2048,constrained_embedding=True,embedding=0,adapt=adagrad,item_key=ItemId,session_key=SessionId,time_key=Time -m 1 5 10 20
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# Using cuDNN version 7104 on context None
# Mapped name None to device cuda0: NVIDIA GeForce GTX TITAN X (0000:02:00.0)
# SET   layers                  TO   [128]       (type: <class 'list'>)
# SET   loss                    TO   bpr-max     (type: <class 'str'>)
# SET   bpreg                   TO   0.35        (type: <class 'float'>)
# SET   logq                    TO   0.0         (type: <class 'float'>)
# SET   final_act               TO   elu-1       (type: <class 'str'>)
# SET   hidden_act              TO   tanh        (type: <class 'str'>)
# SET   n_epochs                TO   10          (type: <class 'int'>)
# SET   batch_size              TO   32          (type: <class 'int'>)
# SET   dropout_p_embed         TO   0.5         (type: <class 'float'>)
# SET   dropout_p_hidden        TO   0.1         (type: <class 'float'>)
# SET   learning_rate           TO   0.15        (type: <class 'float'>)
# SET   momentum                TO   0.1         (type: <class 'float'>)
# SET   sample_alpha            TO   0.2         (type: <class 'float'>)
# SET   n_sample                TO   2048        (type: <class 'int'>)
# SET   constrained_embedding   TO   True        (type: <class 'bool'>)
# SET   embedding               TO   0           (type: <class 'int'>)
# SET   adapt                   TO   adagrad     (type: <class 'str'>)
# SET   item_key                TO   ItemId      (type: <class 'str'>)
# SET   session_key             TO   SessionId   (type: <class 'str'>)
# SET   time_key                TO   Time        (type: <class 'str'>)
# Loading training data...
# Loading data from TAB separated file: data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_train_full_56D.tsv
# Started training
# The dataframe is already sorted by SessionId, Time
# Created sample store with 4882 batches of samples (type=GPU)
# Epoch1 --> loss: 0.626388 	(9.82s) 	[668.51 mb/s | 21315 e/s]
# Epoch2 --> loss: 0.415689 	(9.65s) 	[680.31 mb/s | 21691 e/s]
# Epoch3 --> loss: 0.338020 	(9.62s) 	[682.41 mb/s | 21758 e/s]
# Epoch4 --> loss: 0.302097 	(9.61s) 	[682.78 mb/s | 21770 e/s]
# Epoch5 --> loss: 0.281617 	(9.63s) 	[681.69 mb/s | 21735 e/s]
# Epoch6 --> loss: 0.268451 	(9.58s) 	[684.76 mb/s | 21833 e/s]
# Epoch7 --> loss: 0.258587 	(9.60s) 	[683.35 mb/s | 21788 e/s]
# Epoch8 --> loss: 0.251200 	(9.60s) 	[683.44 mb/s | 21791 e/s]
# Epoch9 --> loss: 0.245005 	(9.57s) 	[685.54 mb/s | 21858 e/s]
# Epoch10 --> loss: 0.239889 	(9.63s) 	[681.42 mb/s | 21727 e/s]
# Total training time: 116.31s
# Loading test data...
# Loading data from TAB separated file: data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_test.tsv
# Starting evaluation (cut-off=1, using standard mode for tiebreaking)
# Measuring Recall@1 and MRR@1
# Evaluation took 5.88s
# Recall@1: 0.106865 MRR@1: 0.106865
# Starting evaluation (cut-off=5, using standard mode for tiebreaking)
# Measuring Recall@5 and MRR@5
# Evaluation took 1.46s
# Recall@5: 0.277319 MRR@5: 0.167699
# Starting evaluation (cut-off=10, using standard mode for tiebreaking)
# Measuring Recall@10 and MRR@10
# Evaluation took 1.44s
# Recall@10: 0.365349 MRR@10: 0.179445
# Starting evaluation (cut-off=20, using standard mode for tiebreaking)
# Measuring Recall@20 and MRR@20
# Evaluation took 1.45s
# Recall@20: 0.452592 MRR@20: 0.185499
# executing script:
# THEANO_FLAGS=device=cuda0 python ./GRU4Rec/run.py data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_train_full_28D.tsv -t data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_test.tsv -g gru4rec -ps layers=192,loss=bpr-max,bpreg=1.35,logq=0.0,final_act=linear,hidden_act=tanh,n_epochs=10,batch_size=64,dropout_p_embed=0.45,dropout_p_hidden=0.05,learning_rate=0.045,momentum=0.3,sample_alpha=0.0,n_sample=2048,constrained_embedding=True,embedding=0,adapt=adagrad,item_key=ItemId,session_key=SessionId,time_key=Time -m 1 5 10 20
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# Using cuDNN version 7104 on context None
# Mapped name None to device cuda0: NVIDIA GeForce GTX TITAN X (0000:02:00.0)
# SET   layers                  TO   [192]       (type: <class 'list'>)
# SET   loss                    TO   bpr-max     (type: <class 'str'>)
# SET   bpreg                   TO   1.35        (type: <class 'float'>)
# SET   logq                    TO   0.0         (type: <class 'float'>)
# SET   final_act               TO   linear      (type: <class 'str'>)
# SET   hidden_act              TO   tanh        (type: <class 'str'>)
# SET   n_epochs                TO   10          (type: <class 'int'>)
# SET   batch_size              TO   64          (type: <class 'int'>)
# SET   dropout_p_embed         TO   0.45        (type: <class 'float'>)
# SET   dropout_p_hidden        TO   0.05        (type: <class 'float'>)
# SET   learning_rate           TO   0.045       (type: <class 'float'>)
# SET   momentum                TO   0.3         (type: <class 'float'>)
# SET   sample_alpha            TO   0.0         (type: <class 'float'>)
# SET   n_sample                TO   2048        (type: <class 'int'>)
# SET   constrained_embedding   TO   True        (type: <class 'bool'>)
# SET   embedding               TO   0           (type: <class 'int'>)
# SET   adapt                   TO   adagrad     (type: <class 'str'>)
# SET   item_key                TO   ItemId      (type: <class 'str'>)
# SET   session_key             TO   SessionId   (type: <class 'str'>)
# SET   time_key                TO   Time        (type: <class 'str'>)
# Loading training data...
# Loading data from TAB separated file: data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_train_full_28D.tsv
# Started training
# The dataframe is already sorted by SessionId, Time
# Created sample store with 4882 batches of samples (type=GPU)
# Epoch1 --> loss: 0.581857 	(2.33s) 	[647.80 mb/s | 39989 e/s]
# Epoch2 --> loss: 0.439149 	(2.32s) 	[651.20 mb/s | 40198 e/s]
# Epoch3 --> loss: 0.374486 	(2.32s) 	[652.31 mb/s | 40267 e/s]
# Epoch4 --> loss: 0.338681 	(2.34s) 	[644.77 mb/s | 39801 e/s]
# Epoch5 --> loss: 0.317032 	(2.33s) 	[649.88 mb/s | 40117 e/s]
# Epoch6 --> loss: 0.302595 	(2.32s) 	[650.51 mb/s | 40156 e/s]
# Epoch7 --> loss: 0.292494 	(2.34s) 	[646.06 mb/s | 39881 e/s]
# Epoch8 --> loss: 0.284284 	(2.33s) 	[649.77 mb/s | 40110 e/s]
# Epoch9 --> loss: 0.278621 	(2.32s) 	[650.76 mb/s | 40171 e/s]
# Epoch10 --> loss: 0.273789 	(2.33s) 	[647.97 mb/s | 39999 e/s]
# Total training time: 42.04s
# Loading test data...
# Loading data from TAB separated file: data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_test.tsv
# Starting evaluation (cut-off=1, using standard mode for tiebreaking)
# Measuring Recall@1 and MRR@1
# Evaluation took 5.49s
# Recall@1: 0.104059 MRR@1: 0.104059
# Starting evaluation (cut-off=5, using standard mode for tiebreaking)
# Measuring Recall@5 and MRR@5
# Evaluation took 1.19s
# Recall@5: 0.262298 MRR@5: 0.160447
# Starting evaluation (cut-off=10, using standard mode for tiebreaking)
# Measuring Recall@10 and MRR@10
# Evaluation took 1.19s
# Recall@10: 0.345556 MRR@10: 0.171560
# Starting evaluation (cut-off=20, using standard mode for tiebreaking)
# Measuring Recall@20 and MRR@20
# Evaluation took 1.19s
# Recall@20: 0.427487 MRR@20: 0.177277
# executing script:
# THEANO_FLAGS=device=cuda0 python ./GRU4Rec/run.py data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_train_full_14D.tsv -t data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_test.tsv -g gru4rec -ps layers=96,loss=bpr-max,bpreg=0.5,logq=0.0,final_act=elu-1,hidden_act=tanh,n_epochs=10,batch_size=176,dropout_p_embed=0.05,dropout_p_hidden=0.0,learning_rate=0.115,momentum=0.65,sample_alpha=0.6,n_sample=2048,constrained_embedding=True,embedding=0,adapt=adagrad,item_key=ItemId,session_key=SessionId,time_key=Time -m 1 5 10 20
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# Using cuDNN version 7104 on context None
# Mapped name None to device cuda0: NVIDIA GeForce GTX TITAN X (0000:02:00.0)
# SET   layers                  TO   [96]        (type: <class 'list'>)
# SET   loss                    TO   bpr-max     (type: <class 'str'>)
# SET   bpreg                   TO   0.5         (type: <class 'float'>)
# SET   logq                    TO   0.0         (type: <class 'float'>)
# SET   final_act               TO   elu-1       (type: <class 'str'>)
# SET   hidden_act              TO   tanh        (type: <class 'str'>)
# SET   n_epochs                TO   10          (type: <class 'int'>)
# SET   batch_size              TO   176         (type: <class 'int'>)
# SET   dropout_p_embed         TO   0.05        (type: <class 'float'>)
# SET   dropout_p_hidden        TO   0.0         (type: <class 'float'>)
# SET   learning_rate           TO   0.115       (type: <class 'float'>)
# SET   momentum                TO   0.65        (type: <class 'float'>)
# SET   sample_alpha            TO   0.6         (type: <class 'float'>)
# SET   n_sample                TO   2048        (type: <class 'int'>)
# SET   constrained_embedding   TO   True        (type: <class 'bool'>)
# SET   embedding               TO   0           (type: <class 'int'>)
# SET   adapt                   TO   adagrad     (type: <class 'str'>)
# SET   item_key                TO   ItemId      (type: <class 'str'>)
# SET   session_key             TO   SessionId   (type: <class 'str'>)
# SET   time_key                TO   Time        (type: <class 'str'>)
# Loading training data...
# Loading data from TAB separated file: data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_train_full_14D.tsv
# Started training
# The dataframe is already sorted by SessionId, Time
# Created sample store with 4882 batches of samples (type=GPU)
# Epoch1 --> loss: 0.647860 	(0.58s) 	[623.38 mb/s | 80983 e/s]
# Epoch2 --> loss: 0.447631 	(0.58s) 	[622.81 mb/s | 80909 e/s]
# Epoch3 --> loss: 0.318978 	(0.58s) 	[624.06 mb/s | 81071 e/s]
# Epoch4 --> loss: 0.249779 	(0.58s) 	[625.86 mb/s | 81304 e/s]
# Epoch5 --> loss: 0.220434 	(0.58s) 	[626.22 mb/s | 81352 e/s]
# Epoch6 --> loss: 0.205026 	(0.58s) 	[623.34 mb/s | 80978 e/s]
# Epoch7 --> loss: 0.195653 	(0.58s) 	[626.35 mb/s | 81368 e/s]
# Epoch8 --> loss: 0.189487 	(0.58s) 	[622.86 mb/s | 80914 e/s]
# Epoch9 --> loss: 0.184638 	(0.58s) 	[624.81 mb/s | 81168 e/s]
# Epoch10 --> loss: 0.181391 	(0.58s) 	[623.27 mb/s | 80968 e/s]
# Total training time: 24.68s
# Loading test data...
# Loading data from TAB separated file: data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_test.tsv
# Starting evaluation (cut-off=1, using standard mode for tiebreaking)
# Measuring Recall@1 and MRR@1
# Evaluation took 5.27s
# Recall@1: 0.071687 MRR@1: 0.071687
# Starting evaluation (cut-off=5, using standard mode for tiebreaking)
# Measuring Recall@5 and MRR@5
# Evaluation took 0.99s
# Recall@5: 0.189214 MRR@5: 0.113584
# Starting evaluation (cut-off=10, using standard mode for tiebreaking)
# Measuring Recall@10 and MRR@10
# Evaluation took 0.98s
# Recall@10: 0.247252 MRR@10: 0.121453
# Starting evaluation (cut-off=20, using standard mode for tiebreaking)
# Measuring Recall@20 and MRR@20
# Evaluation took 0.98s
# Recall@20: 0.299372 MRR@20: 0.125097
# executing script:
# THEANO_FLAGS=device=cuda0 python ./GRU4Rec/run.py data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_train_full_7D.tsv -t data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_test.tsv -g gru4rec -ps layers=224,loss=bpr-max,bpreg=0.85,logq=0.0,final_act=linear,hidden_act=tanh,n_epochs=10,batch_size=64,dropout_p_embed=0.3,dropout_p_hidden=0.3,learning_rate=0.025,momentum=0.15,sample_alpha=0.2,n_sample=2048,constrained_embedding=True,embedding=0,adapt=adagrad,item_key=ItemId,session_key=SessionId,time_key=Time -m 1 5 10 20
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# Using cuDNN version 7104 on context None
# Mapped name None to device cuda0: NVIDIA GeForce GTX TITAN X (0000:02:00.0)
# SET   layers                  TO   [224]       (type: <class 'list'>)
# SET   loss                    TO   bpr-max     (type: <class 'str'>)
# SET   bpreg                   TO   0.85        (type: <class 'float'>)
# SET   logq                    TO   0.0         (type: <class 'float'>)
# SET   final_act               TO   linear      (type: <class 'str'>)
# SET   hidden_act              TO   tanh        (type: <class 'str'>)
# SET   n_epochs                TO   10          (type: <class 'int'>)
# SET   batch_size              TO   64          (type: <class 'int'>)
# SET   dropout_p_embed         TO   0.3         (type: <class 'float'>)
# SET   dropout_p_hidden        TO   0.3         (type: <class 'float'>)
# SET   learning_rate           TO   0.025       (type: <class 'float'>)
# SET   momentum                TO   0.15        (type: <class 'float'>)
# SET   sample_alpha            TO   0.2         (type: <class 'float'>)
# SET   n_sample                TO   2048        (type: <class 'int'>)
# SET   constrained_embedding   TO   True        (type: <class 'bool'>)
# SET   embedding               TO   0           (type: <class 'int'>)
# SET   adapt                   TO   adagrad     (type: <class 'str'>)
# SET   item_key                TO   ItemId      (type: <class 'str'>)
# SET   session_key             TO   SessionId   (type: <class 'str'>)
# SET   time_key                TO   Time        (type: <class 'str'>)
# Loading training data...
# Loading data from TAB separated file: data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_train_full_7D.tsv
# Started training
# The dataframe is already sorted by SessionId, Time
# Created sample store with 4882 batches of samples (type=GPU)
# Epoch1 --> loss: 0.664363 	(0.72s) 	[608.06 mb/s | 34138 e/s]
# Epoch2 --> loss: 0.586031 	(0.69s) 	[633.90 mb/s | 35589 e/s]
# Epoch3 --> loss: 0.526042 	(0.69s) 	[634.09 mb/s | 35599 e/s]
# Epoch4 --> loss: 0.464833 	(0.69s) 	[633.28 mb/s | 35554 e/s]
# Epoch5 --> loss: 0.406784 	(0.68s) 	[638.85 mb/s | 35867 e/s]
# Epoch6 --> loss: 0.359948 	(0.68s) 	[639.51 mb/s | 35903 e/s]
# Epoch7 --> loss: 0.324353 	(0.69s) 	[634.50 mb/s | 35622 e/s]
# Epoch8 --> loss: 0.298828 	(0.68s) 	[639.59 mb/s | 35908 e/s]
# Epoch9 --> loss: 0.280050 	(0.68s) 	[638.73 mb/s | 35860 e/s]
# Epoch10 --> loss: 0.266844 	(0.68s) 	[636.27 mb/s | 35722 e/s]
# Total training time: 25.63s
# Loading test data...
# Loading data from TAB separated file: data/data_sources/retailrocket_ecommerce/retailrocket_processed_view_test.tsv
# Starting evaluation (cut-off=1, using standard mode for tiebreaking)
# Measuring Recall@1 and MRR@1
# Evaluation took 5.09s
# Recall@1: 0.093659 MRR@1: 0.093659
# Starting evaluation (cut-off=5, using standard mode for tiebreaking)
# Measuring Recall@5 and MRR@5
# Evaluation took 0.81s
# Recall@5: 0.236143 MRR@5: 0.144214
# Starting evaluation (cut-off=10, using standard mode for tiebreaking)
# Measuring Recall@10 and MRR@10
# Evaluation took 0.80s
# Recall@10: 0.304629 MRR@10: 0.153379
# Starting evaluation (cut-off=20, using standard mode for tiebreaking)
# Measuring Recall@20 and MRR@20
# Evaluation took 0.86s
# Recall@20: 0.366512 MRR@20: 0.157682
